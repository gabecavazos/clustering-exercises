# %%
#standard ds
import pandas as pd
import numpy as np

#viz and stats
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

#splits, scale
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import wrangle_zillow as wrangle

# %%
zillow = pd.read_csv('zillow.csv')

# %%
#zillow = wrangle.wrangle_zillow()

# %%
wrangle.missing_value_summary(zillow)
# Out:
#                        Num Missing  Percent Missing
# buildingclassdesc            77365            99.98
# buildingclasstypeid          77365            99.98
# finishedsquarefeet13         77339            99.95
# storytypeid                  77330            99.94
# basementsqft                 77330            99.94
# ...                            ...              ...
# latitude                         0             0.00
# fips                             0             0.00
# bedrooms                         0             0.00
# bathrooms                        0             0.00
# propertylandusetypeid            0             0.00
#
# [68 rows x 2 columns]

# %%
zillow = wrangle.handle_missing_values(zillow)

# %%
wrangle.missing_value_summary(zillow)
# Out:
#                             Num Missing  Percent Missing
# heatingorsystemdesc               27745            35.95
# heatingorsystemtypeid             27745            35.95
# buildingqualitytypeid             27514            35.65
# propertyzoningdesc                26912            34.87
# unitcnt                           26622            34.49
# lotsizesquarefeet                  8157            10.57
# finishedsquarefeet12               3440             4.46
# regionidcity                       1454             1.88
# calculatedbathnbr                   417             0.54
# fullbathcnt                         417             0.54
# censustractandblock                 220             0.29
# structuretaxvaluedollarcnt           85             0.11
# year_built                           83             0.11
# regionidzip                          41             0.05
# area                                 14             0.02
# taxamount                             5             0.01
# landtaxvaluedollarcnt                 1             0.00
# tax_value                             1             0.00
# assessmentyear                        0             0.00
# logerror                              0             0.00
# transactiondate                       0             0.00
# id                                    0             0.00
# rawcensustractandblock                0             0.00
# roomcnt                               0             0.00
# regionidcounty                        0             0.00
# parcelid                              0             0.00
# propertylandusetypeid                 0             0.00
# propertycountylandusecode             0             0.00
# longitude                             0             0.00
# latitude                              0             0.00
# fips                                  0             0.00
# bedrooms                              0             0.00
# bathrooms                             0             0.00
# propertylandusedesc                   0             0.00

# %%
zillow.dropna(inplace = True)

# %%
df = zillow

# %%
wrangle.get_box(df)

# %%
wrangle.get_hist(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in ticklabel_format(self, axis, style, scilimits, useOffset, useLocale, useMathText)
#    3304                 if useOffset is not None:
# -> 3305                     axis.major.formatter.set_useOffset(useOffset)
#    3306                 if useLocale is not None:
#
# AttributeError: 'StrCategoryFormatter' object has no attribute 'set_useOffset'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29016\2733908170.py in <module>
# ----> 1 wrangle.get_hist(df)
#
# ~\codeup-data-science\clustering-exercises\wrangle_zillow.py in get_hist(df)
#     232
#     233         # turn off scientific notation
# --> 234         plt.ticklabel_format(useOffset=False)
#     235
#     236         plt.tight_layout()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in ticklabel_format(axis, style, scilimits, useOffset, useLocale, useMathText)
#    2951         *, axis='both', style='', scilimits=None, useOffset=None,
#    2952         useLocale=None, useMathText=None):
# -> 2953     return gca().ticklabel_format(
#    2954         axis=axis, style=style, scilimits=scilimits,
#    2955         useOffset=useOffset, useLocale=useLocale,
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in ticklabel_format(self, axis, style, scilimits, useOffset, useLocale, useMathText)
#    3309                     axis.major.formatter.set_useMathText(useMathText)
#    3310         except AttributeError as err:
# -> 3311             raise AttributeError(
#    3312                 "This method only works with the ScalarFormatter") from err
#    3313
#
# AttributeError: This method only works with the ScalarFormatter
